# %% [markdown]
# ***Data Analysis***

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif

# %%
df = pd.read_csv('college_student_placement_dataset.csv')

# %%
# Placement Distribution
df['Placement'].value_counts().plot(kind='pie', autopct='%1.1f%%', colors=['lightcoral', 'lightblue']).set_title('Placement Status Distribution')
# Out:
# Text(0.5, 1.0, 'Placement Status Distribution')

# %%
# CGPA Distribution by Placement
placed_cgpa = df[df['Placement'] == 'Yes']['CGPA']
not_placed_cgpa = df[df['Placement'] == 'No']['CGPA']

sns.histplot(
    data=df,
    x='CGPA',
    hue='Placement',
    kde=True,
    stat='density',
    alpha=0.6
)
# Out:
# <Axes: xlabel='CGPA', ylabel='Density'>

# %%
sns.barplot(
    data=df,
    x='Internship_Experience',
    y=df.index,   # implicit count
    estimator=len
)
# Out:
# <Axes: xlabel='Internship_Experience', ylabel='None'>

# %%
# IQ Distribution

sns.histplot(
    data = df,
    x = 'IQ',
    hue = 'Placement',
    kde = True,
    alpha = 0.6
)
# Out:
# <Axes: xlabel='IQ', ylabel='Count'>

# %%
#  Communication Skills by Placement
comm_skills_placed = df[df['Placement'] == 'Yes']['Communication_Skills']
comm_skills_not_placed = df[df['Placement'] == 'No']['Communication_Skills']

sns.histplot(
    data=df,
    x='Communication_Skills',
    hue='Placement',
    bins=10
)
# Out:
# <Axes: xlabel='Communication_Skills', ylabel='Count'>

# %%
# Projects Completed

ax = sns.barplot(
    data=df,
    x='Projects_Completed',
    y=df.index,
    estimator=len
)

ax.set_xlabel('Projects Completed')
ax.set_ylabel('Number of Students')
ax.set_title('Students Count by Projects Completed')
# Out:
# Text(0.5, 1.0, 'Students Count by Projects Completed')

# %%
# Academic Performance

ax = sns.histplot(
    data = df,
    x = 'Academic_Performance',
    bins = 10
)

ax.set_title('Academic Performance Distribution')
ax.set_xlabel('Academic Performance')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Previous Semester Result

ax = sns.histplot(
    data=df,
    x='Prev_Sem_Result',
    bins=10
)

ax.set_title('Previous Semester Result Distribution')
ax.set_xlabel('Previous Semester Result')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
# Extra Curricular Activities
ax = sns.barplot(
    data=df,
    x='Extra_Curricular_Score',
    y=df.index,
    estimator=len
)
ax.set_xlabel('Extra Curricular Score')
ax.set_ylabel('Number of Students')
ax.set_title('Students Count by Extra Curricular Score')
# Out:
# Text(0.5, 1.0, 'Students Count by Extra Curricular Score')
